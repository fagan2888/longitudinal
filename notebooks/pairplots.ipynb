# %%
import pandas as pd
import seaborn as sns
import numpy as np
df = pd.read_csv("data/d_lr_example_patients_lab_max.csv")
df.drop(columns = ['id'], inplace=True)
#plot = sns.pairplot(data = df[['classification, race, sex']])
plot = sns.pairplot(data = df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.conda/envs/epistasis/lib/python3.7/site-packages/numpy/lib/histograms.py in _unsigned_subtract(a, b)
#     341             else:
# --> 342                 # Width can be zero for some estimators, e.g. FD when
#     343                 # the IQR of the data is zero.
#
# KeyError: <class 'numpy.bool_'>
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-0ada1a4a8caa> in <module>
#       5 df.drop(columns = ['id'], inplace=True)
#       6 #plot = sns.pairplot(data = df[['classification, race, sex']])
# ----> 7 plot = sns.pairplot(data = df)
#
# ...
